# %%
# testing
# Import necessary modules
import data_preprocessor as dp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# 1. Load the dataset
messy_data = pd.read_csv('../Data/messy_data.csv')

# 2. Data Exploration Messy Data
print("Messy Data Info")
display(messy_data.info())
print("Messy Data Description")
display(messy_data.describe(include='all'))
print("Missing Values in Messy Data")
display(messy_data.isnull().sum())

# Data visualisation: Histograms
numeric_cols = messy_data.select_dtypes(include='number').columns
messy_data[numeric_cols].hist(bins=20, figsize=(15, 10))
plt.suptitle("Messy Data - Histograms", fontsize=16)
plt.tight_layout()
plt.show()

# 3. Preprocess the data
print("Preprocess the data")
clean_data = messy_data.copy()
clean_data = dp.impute_missing_values(clean_data, strategy='mean')
clean_data = dp.remove_duplicates(clean_data)
clean_data = dp.normalize_data(clean_data)
clean_data = dp.remove_redundant_features(clean_data)

# 4. Save the cleaned dataset
clean_data.to_csv('../Data/clean_data.csv', index=False)

#5. Explore the cleaned dataset
print("Clean Data Info")
display(clean_data.info())
print("Clean Data Description")
display(clean_data.describe(include='all'))
print("Missing Values in Clean Data")
display(clean_data.isnull().sum())

# Histograms
numeric_cols = clean_data.select_dtypes(include='number').columns
clean_data[numeric_cols].hist(bins=20, figsize=(15, 10))
plt.suptitle("Clean Data - Histograms", fontsize=16)
plt.tight_layout()
plt.show()


#5. Train and evaluate the model
dp.simple_model(clean_data, scale_data=True, print_report=True, target_col="target")
# Out:
# Messy Data Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1196 entries, 0 to 1195
# Data columns (total 28 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  920 non-null    float64
#  1   a       1193 non-null   object
#  2   b       1196 non-null   float64
#  3   c       1196 non-null   int64
#  4   d       561 non-null    object
#  5   e       1196 non-null   object
#  6   f       1196 non-null   float64
#  7   g       1196 non-null   object
#  8   h       1158 non-null   float64
#  9   i       1087 non-null   object
#  10  j       591 non-null    float64
#  11  k       1196 non-null   float64
#  12  l       1196 non-null   float64
#  13  m       778 non-null    object
#  14  n       1012 non-null   float64
#  15  o       1008 non-null   float64
#  16  p       1122 non-null   float64
#  17  q       1009 non-null   float64
#  18  r       1196 non-null   float64
#  19  s       1196 non-null   object
#  20  t       1110 non-null   float64
#  21  u       1079 non-null   float64
#  22  v       1116 non-null   float64
#  23  w       1079 non-null   float64
#  24  x       397 non-null    float64
#  25  y       1196 non-null   float64
#  26  z       598 non-null    float64
#  27  {       1122 non-null   object
# dtypes: float64(19), int64(1), object(8)
# memory usage: 261.8+ KB
# None
# Messy Data Description
#             target       a            b            c                  d  \
# count   920.000000    1193  1196.000000  1196.000000                561
# unique         NaN       3          NaN          NaN                  3
# top            NaN  normal          NaN          NaN  reversable defect
# freq           NaN     720          NaN          NaN                254
# mean      0.553261     NaN     0.004015    53.383779                NaN
# std       0.497426     NaN     0.984837     9.534033                NaN
# min       0.000000     NaN    -3.308750    28.000000                NaN
# 25%       0.000000     NaN    -0.692960    47.000000                NaN
# 50%       1.000000     NaN     0.004241    54.000000                NaN
# 75%       1.000000     NaN     0.714572    60.000000                NaN
# max       1.000000     NaN     2.982511    77.000000                NaN
#
#                 e            f             g            h      i  ...  \
# count        1196  1196.000000          1196  1158.000000   1087  ...
# unique          4          NaN             4          NaN      2  ...
# top     Cleveland          NaN  asymptomatic          NaN  False  ...
# freq          392          NaN           644          NaN    900  ...
# mean          NaN     0.001391           NaN   200.583765    NaN  ...
# std           NaN     1.011656           NaN   110.061582    NaN  ...
# min           NaN    -2.820047           NaN     0.000000    NaN  ...
# 25%           NaN    -0.633350           NaN   176.250000    NaN  ...
# 50%           NaN    -0.051965           NaN   224.000000    NaN  ...
# 75%           NaN     0.693539           NaN   270.000000    NaN  ...
# max           NaN     3.323155           NaN   603.000000    NaN  ...
#
#                   r     s            t            u            v            w  \
# count   1196.000000  1196  1110.000000  1079.000000  1116.000000  1079.000000
# unique          NaN     2          NaN          NaN          NaN          NaN
# top             NaN  Male          NaN          NaN          NaN          NaN
# freq            NaN   946          NaN          NaN          NaN          NaN
# mean      53.376221   NaN     0.872252    53.328760   132.247312     0.034028
# std        9.603964   NaN     1.077211     9.645423    18.872281     0.995701
# min       27.548190   NaN    -2.600000    28.743286     0.000000    -3.087673
# 25%       46.857255   NaN     0.000000    46.541317   120.000000    -0.601836
# 50%       54.126896   NaN     0.500000    54.148423   130.000000     0.035589
# 75%       60.324072   NaN     1.500000    60.418600   140.000000     0.723486
# max       77.484697   NaN     6.200000    78.520864   200.000000     3.933288
#
#                  x            y           z      {
# count   397.000000  1196.000000  598.000000   1122
# unique         NaN          NaN         NaN      2
# top            NaN          NaN         NaN  False
# freq           NaN          NaN         NaN    689
# mean      0.667506    53.379991   -0.757779    NaN
# std       0.924021     9.564497    1.257376    NaN
# min       0.000000    26.549257   -7.293222    NaN
# 25%       0.000000    46.931375   -1.316941    NaN
# 50%       0.000000    54.448992   -0.439484    NaN
# 75%       1.000000    59.812460    0.094453    NaN
# max       3.000000    79.712348    1.202416    NaN
#
# [11 rows x 28 columns]
# Missing Values in Messy Data
# target    276
# a           3
# b           0
# c           0
# d         635
# e           0
# f           0
# g           0
# h          38
# i         109
# j         605
# k           0
# l           0
# m         418
# n         184
# o         188
# p          74
# q         187
# r           0
# s           0
# t          86
# u         117
# v          80
# w         117
# x         799
# y           0
# z         598
# {          74
# dtype: int64
# Preprocess the data
# Clean Data Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1196 entries, 0 to 1195
# Data columns (total 22 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  1196 non-null   float64
#  1   a       1196 non-null   object
#  2   b       1196 non-null   float64
#  3   c       1196 non-null   float64
#  4   d       1196 non-null   object
#  5   e       1196 non-null   object
#  6   f       1196 non-null   float64
#  7   g       1196 non-null   object
#  8   h       1196 non-null   float64
#  9   i       1196 non-null   bool
#  10  j       1196 non-null   float64
#  11  k       1196 non-null   float64
#  12  l       1196 non-null   float64
#  13  m       1196 non-null   object
#  14  n       1196 non-null   float64
#  15  s       1196 non-null   object
#  16  t       1196 non-null   float64
#  17  v       1196 non-null   float64
#  18  w       1196 non-null   float64
#  19  x       1196 non-null   float64
#  20  z       1196 non-null   float64
#  21  {       1196 non-null   bool
# dtypes: bool(2), float64(14), object(6)
# memory usage: 189.3+ KB
# c:\Users\HP EliteBook\Desktop\ML Lab\Assignment1\Assignment1\Scripts\data_preprocessor.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[col].fillna(data[col].mean(), inplace=True)
# c:\Users\HP EliteBook\Desktop\ML Lab\Assignment1\Assignment1\Scripts\data_preprocessor.py:30: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[col].fillna(data[col].mode()[0], inplace=True)
# c:\Users\HP EliteBook\Desktop\ML Lab\Assignment1\Assignment1\Scripts\data_preprocessor.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[col].fillna(data[col].mode()[0], inplace=True)
# None
# Clean Data Description
#              target       a            b            c                  d  \
# count   1196.000000    1196  1196.000000  1196.000000               1196
# unique          NaN       3          NaN          NaN                  3
# top             NaN  normal          NaN          NaN  reversable defect
# freq            NaN     723          NaN          NaN                889
# mean       0.553261     NaN     0.526566     0.518036                NaN
# std        0.436216     NaN     0.156540     0.194572                NaN
# min        0.000000     NaN     0.000000     0.000000                NaN
# 25%        0.000000     NaN     0.415781     0.387755                NaN
# 50%        0.553261     NaN     0.526602     0.530612                NaN
# 75%        1.000000     NaN     0.639510     0.653061                NaN
# max        1.000000     NaN     1.000000     1.000000                NaN
#
#                 e            f             g            h      i  ...  \
# count        1196  1196.000000          1196  1196.000000   1196  ...
# unique          4          NaN             4          NaN      2  ...
# top     Cleveland          NaN  asymptomatic          NaN  False  ...
# freq          392          NaN           644          NaN   1009  ...
# mean          NaN     0.459278           NaN     0.332643    NaN  ...
# std           NaN     0.164679           NaN     0.179598    NaN  ...
# min           NaN     0.000000           NaN     0.000000    NaN  ...
# 25%           NaN     0.355954           NaN     0.296849    NaN  ...
# 50%           NaN     0.450593           NaN     0.369818    NaN  ...
# 75%           NaN     0.571947           NaN     0.444859    NaN  ...
# max           NaN     1.000000           NaN     1.000000    NaN  ...
#
#                   l     m            n     s            t            v  \
# count   1196.000000  1196  1196.000000  1196  1196.000000  1196.000000
# unique          NaN     3          NaN     2          NaN          NaN
# top             NaN  flat          NaN  Male          NaN          NaN
# freq            NaN   873          NaN   946          NaN          NaN
# mean       0.454950   NaN     0.687651   NaN     0.394574     0.661237
# std        0.156389   NaN     0.156296   NaN     0.117923     0.091148
# min        0.000000   NaN     0.000000   NaN     0.000000     0.000000
# 25%        0.353222   NaN     0.602107   NaN     0.295455     0.600000
# 50%        0.457102   NaN     0.687651   NaN     0.380682     0.650000
# 75%        0.561959   NaN     0.799732   NaN     0.465909     0.700000
# max        1.000000   NaN     1.000000   NaN     1.000000     1.000000
#
#                   w            x            z      {
# count   1196.000000  1196.000000  1196.000000   1196
# unique          NaN          NaN          NaN      2
# top             NaN          NaN          NaN  False
# freq            NaN          NaN          NaN    763
# mean       0.444626     0.222502     0.769270    NaN
# std        0.134697     0.177306     0.104610    NaN
# min        0.000000     0.000000     0.000000    NaN
# 25%        0.365728     0.222502     0.769270    NaN
# 50%        0.444626     0.222502     0.769270    NaN
# 75%        0.524538     0.222502     0.806438    NaN
# max        1.000000     1.000000     1.000000    NaN
#
# [11 rows x 22 columns]
# Missing Values in Clean Data
# target    0
# a         0
# b         0
# c         0
# d         0
# e         0
# f         0
# g         0
# h         0
# i         0
# j         0
# k         0
# l         0
# m         0
# n         0
# s         0
# t         0
# v         0
# w         0
# x         0
# z         0
# {         0
# dtype: int64
# Model Accuracy: 0.7792
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.69      0.63      0.66        82
#            1       0.82      0.85      0.84       158
#
#     accuracy                           0.78       240
#    macro avg       0.76      0.74      0.75       240
# weighted avg       0.78      0.78      0.78       240
